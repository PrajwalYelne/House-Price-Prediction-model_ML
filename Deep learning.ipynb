# %%
import opencv as cv2
import tensorflow as tf

CATEGORIES = ["Dog", "Cat"]

def prepare(filepath):
    IMG_SIZe = 70
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resizw(img_array,(IMG_SIZE, IMG_SIZE))
    return mew_arrey.shape(-1, IMG_SIZE, IMG_SIZE, 1)

MODEL = tf.kears.models.load-model("64x3-CNN.model")

prediction = model.predict(prepare['2msowf.jpg'])
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0324ec9b946b> in <module>
# ----> 1 import opencv as cv2
#       2 import tensorflow as tf
#       3
#       4 CATEGORIES = ["Dog", "Cat"]
#       5
#
# ModuleNotFoundError: No module named 'opencv'
